# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print('hello world')
# Out:
# hello world

# %%
iris = pd.read_csv('C:\\Users\\admin\\Desktop\\Python\\iris.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
iris.shape
print(iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris['species'].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %%
iris.plot(kind ='scatter', x='sepal_length', y='sepal_width');
plt.grid()
plt.show()

# %%
sns.set_style("darkgrid");
sns.FacetGrid(iris, hue="species", size=5) \
   .map(plt.scatter,"sepal_length","sepal_width") \
   .add_legend();
plt.show();

# %%
plt.close();

# %%
sns.set_style('darkgrid')
sns.pairplot(iris, hue='species', size=3)
plt.show()

# %%
sns.FacetGrid(iris , hue='species', size=8) \
   .map(sns.distplot, 'petal_length') \
   .add_legend();
plt.show();
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(iris, hue='species' , size = 10) \
   .map(sns.distplot , 'sepal_width') \
   .add_legend();
plt.show();
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
iris_setosa = iris.loc[iris['species'] == 'setosa'];
iris_virginica = iris.loc[iris['species'] == 'virginica'];
iris_versicolor = iris.loc[iris['species'] == 'versicolor'];

plt.plot(iris_setosa['petal_length'],np.zeros_like(iris_setosa['petal_length']), 'o')
plt.plot(iris_versicolor['petal_length'],np.zeros_like(iris_versicolor['petal_length']), 'o')
plt.plot(iris_virginica['petal_length'],np.zeros_like(iris_virginica['petal_length']), 'o')

plt.show()

# %%
counts , bin_edges = np.histogram (iris_setosa['petal_length'] , bins = 10, density = True)

pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)


cdf = np.cumsum(pdf)  # cummulative sum  for cdf 
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show();
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
# Computing mean with np.mean() function
print('means:');
print(np.mean(iris_setosa['petal_length']))
print(np.mean(iris_versicolor['petal_length']))
print(np.mean(iris_virginica['petal_length']))
print(np.mean(np.append(iris_setosa['petal_length'],50)))
# Out:
# means:
# 1.464
# 4.26
# 5.552
# 2.4156862745098038

# %%
# computing standard dev with np.std() function
print('standard deviation')
print(np.std(iris_setosa['petal_length']))
print(np.std(iris_versicolor['petal_length']))
print(np.std(iris_virginica['petal_length']))
# Out:
# standard deviation
# 0.17176728442867115
# 0.4651881339845204
# 0.5463478745268441

# %%
#computing median with np.median() function
print(np.median(iris_setosa["petal_length"]))
print(np.median(np.append(iris_setosa['petal_length'],50)))
print(np.median(iris_versicolor['petal_length']))
print(np.median(iris_virginica['petal_length']))
# Out:
# 1.5
# 1.5
# 4.35
# 5.55

# %%
# computing quartile with np.append() and np.percentile() function.
print(np.percentile(iris_setosa['petal_length'],np.arange(0,100,25)))
print(np.percentile(iris_versicolor['petal_length'],np.arange(0,100,25)))
print(np.percentile(iris_virginica['petal_length'],np.arange(0,100,25)))


# compute 25th percentile with np.percentile () function 
print(np.percentile(iris_setosa['petal_length'],25))
print(np.percentile(iris_versicolor['petal_length'],25))
print(np.percentile(iris_virginica['petal_length'],25))
# Out:
# [1.    1.4   1.5   1.575]
# [3.   4.   4.35 4.6 ]
# [4.5   5.1   5.55  5.875]
# 1.4
# 4.0
# 5.1

# %%
#compute mean standard deviation
from statsmodels import robust
print(robust.mad(iris_setosa['petal_length']))
print(robust.mad(iris_setosa['petal_length']))
print(robust.mad(iris_setosa['petal_length']))
# Out:
# 0.14826022185056031
# 0.14826022185056031
# 0.14826022185056031

# %%
#box-plot with seaborn library 

import seaborn as sns
sns.boxplot(x='species',y='petal_length',data=iris)
plt.show()

# %%
# violin plots.
# they are combination of both histogram and pdf.
# they also look similar to gaussian distribution.
sns.violinplot(x='species',y='petal_length',data = iris, sze = 10)
plt.show()
